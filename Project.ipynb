# %% [markdown]
# This is a deep learning based numerical character reader , this model will detect the hand writen or poorly writen number with the help of alrady available MNIST data.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import  numpy as np
import pandas as pd

# %%
(x_train , y_train),(x_test, y_test)= mnist.load_data()



x_train= x_train.astype("float32")/255
x_test= x_test.astype("float32")/255


x_train = x_train.reshape(-1, 28, 28, 1)
x_test  = x_test.reshape(-1, 28, 28, 1)

# %% [markdown]
# Data augumentation
#
# 1.Rotation
# 2.Flipping
# 3.Zoom
# 4.Brightness
# 5.Shift

# %%
datagen= ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
)

datagen.fit(x_train)

# %%
from tensorflow.keras import models, layers

model = models.Sequential([
     # --- Block 1 ---
        layers.Conv2D(32, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Conv2D(32, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # --- Block 2 ---
        layers.Conv2D(64, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.Conv2D(64, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # --- Block 3 ---
        layers.Conv2D(128, (3, 3), padding="same"),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # --- Classifier Head ---
        layers.Flatten(),
        layers.Dense(256, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(10, activation="softmax")
])

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
model.fit(
    datagen.flow(x_train, y_train, batch_size=32),
    epochs=10
)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 44s 22ms/step - accuracy: 0.8988 - loss: 0.3226
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 55s 29ms/step - accuracy: 0.9649 - loss: 0.1130
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 59s 31ms/step - accuracy: 0.9739 - loss: 0.0867
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 57s 30ms/step - accuracy: 0.9766 - loss: 0.0765
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 62s 33ms/step - accuracy: 0.9798 - loss: 0.0665
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 62s 33ms/step - accuracy: 0.9811 - loss: 0.0614
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 60s 32ms/step - accuracy: 0.9831 - loss: 0.0552
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 64s 34ms/step - accuracy: 0.9845 - loss: 0.0511
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 100s 53ms/step - accuracy: 0.9857 - loss: 0.0492
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 75s 40ms/step - accuracy: 0.9868 - loss: 0.0462

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9947 - loss: 0.0154
# [0.015417180955410004, 0.994700014591217]

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# --- Accuracy ---
axes[0].plot(history.history["accuracy"],     label="Train Accuracy",      linewidth=2)
axes[0].plot(history.history["val_accuracy"], label="Validation Accuracy",  linewidth=2, linestyle="--")
axes[0].set_title("Accuracy over Epochs", fontsize=14, fontweight="bold")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# --- Loss ---
axes[1].plot(history.history["loss"],     label="Train Loss",      linewidth=2, color="orange")
axes[1].plot(history.history["val_loss"], label="Validation Loss",  linewidth=2, linestyle="--", color="red")
axes[1].set_title("Loss over Epochs", fontsize=14, fontweight="bold")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("training_history.png", dpi=150, bbox_inches="tight")
plt.show()
print("Plot saved to training_history.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 fig, axes = plt.subplots(1, 2, figsize=(14, 5))
#       3 # --- Accuracy ---
#       4 axes[0].plot(history.history["accuracy"],     label="Train Accuracy",      linewidth=2)
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

img_path = "./Untitled.png"

def predict_digit(img_path):

    img = image.load_img(img_path, color_mode="grayscale", target_size=(28,28))
    
    img_array = image.img_to_array(img)
    
    img_array = img_array / 255.0

    img_array = 1 - img_array   # invert colors

    img_array = img_array.reshape(1,28,28,1)

    prediction = model.predict(img_array)

    predicted_digit = np.argmax(prediction)

    print("Predicted Digit:", predicted_digit)


predict_digit(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Predicted Digit: 8
